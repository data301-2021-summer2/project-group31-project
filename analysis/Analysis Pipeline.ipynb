# %% [markdown]
# ## Task 1 Analysis Pipeline
# ##### Importing libraries for wrangling and cleaning my dataset

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Read the csv file of my dataset in my raw data folder

# %%
df1 = pd.read_csv('../data/raw/DataEngineer.csv',sep=',') # Comma-seperated values file and Comma-delimited 
df1
# Out:
#                                               Job Title  \
# 0                                         Data Engineer
# 1     Senior Data Engineer (Healthcare Domain experi...
# 2                                        Data Engineers
# 3                         Client Trade Support Engineer
# 4                                         Data Engineer
# ...                                                 ...
# 2523                                     Cloud Engineer
# 2524                                Electrical Engineer
# 2525                              Sr. Big Data Engineer
# 2526                     Senior Big Data / ETL Engineer
# 2527                                     Cloud Engineer
#
#                   Salary Estimate  \
# 0     $80K-$150K (Glassdoor est.)
# 1     $80K-$150K (Glassdoor est.)
# 2     $80K-$150K (Glassdoor est.)
# 3     $80K-$150K (Glassdoor est.)
# 4     $80K-$150K (Glassdoor est.)
# ...                           ...
# 2523  $76K-$128K (Glassdoor est.)
# 2524  $76K-$128K (Glassdoor est.)
# 2525  $76K-$128K (Glassdoor est.)
# 2526  $76K-$128K (Glassdoor est.)
# 2527  $76K-$128K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Company Description\nSagence is a management a...     4.5
# 1     Key Responsibilities\n\n- Architect, build, an...     3.4
# 2     Overview\n\nJob description\n\nPosition Overvi...     5.0
# 3     About the Position\n\n\nThis position will sup...     4.8
# 4     Data Engineer\n\nJob Details\nLevel\nExperienc...     3.7
# ...                                                 ...     ...
# 2523  The Expertise You Have Proven expertise in dev...     4.5
# 2524  Lockheed Martin is seeking a Circuit and FPGA ...     2.9
# 2525  Posting Title Principal Data Engineer (Contrac...     3.7
# 2526  Your Opportunity\n\nCharles Schwab & Co., Inc ...     3.5
# 2527  Cloud Engineer Westlake, TX 6+ months Descript...     3.6
#
#                                    Company Name        Location  \
# 0                                  Sagence\n4.5    New York, NY
# 1                   Enterprise Integration\n3.4    New York, NY
# 2                     Maestro Technologies\n5.0    New York, NY
# 3                              Jane Street\n4.8    New York, NY
# 4                  GNY Insurance Companies\n3.7    New York, NY
# ...                                         ...             ...
# 2523                            PMG Global\n4.5    Westlake, TX
# 2524            Albin Engineering Services\n2.9  Fort Worth, TX
# 2525  Cincinnati Bell Technology Solutions\n3.7      Irving, TX
# 2526                                Schwab\n3.5    Westlake, TX
# 2527        SPECTRAFORCE TECHNOLOGIES Inc.\n3.6    Westlake, TX
#
#              Headquarters                   Size  Founded  Type of ownership  \
# 0             Chicago, IL      1 to 50 employees     2009  Company - Private
# 1        Jacksonville, FL    51 to 200 employees     1998  Company - Private
# 2             Trenton, NJ    51 to 200 employees     2003  Company - Private
# 3            New York, NY  501 to 1000 employees     2000  Company - Private
# 4            New York, NY   201 to 500 employees     1914  Company - Private
# ...                   ...                    ...      ...                ...
# 2523          Herndon, VA      1 to 50 employees       -1  Company - Private
# 2524      Santa Clara, CA    51 to 200 employees     1993  Company - Private
# 2525       Cincinnati, OH  501 to 1000 employees       -1  Company - Private
# 2526  Dettenheim, Germany                Unknown       -1   Company - Public
# 2527          Raleigh, NC  501 to 1000 employees     2000  Company - Private
#
#                                    Industry                  Sector  \
# 0                                Consulting       Business Services
# 1                               IT Services  Information Technology
# 2                               IT Services  Information Technology
# 3     Investment Banking & Asset Management                 Finance
# 4                        Insurance Carriers               Insurance
# ...                                     ...                     ...
# 2523           Computer Hardware & Software  Information Technology
# 2524                 Staffing & Outsourcing       Business Services
# 2525                            IT Services  Information Technology
# 2526                                     -1                      -1
# 2527                 Staffing & Outsourcing       Business Services
#
#                          Revenue                       Competitors Easy Apply
# 0       $10 to $25 million (USD)               WCI Consulting, PwC         -1
# 1       $25 to $50 million (USD)                                -1         -1
# 2        $5 to $10 million (USD)                                -1         -1
# 3       Unknown / Non-Applicable                                -1         -1
# 4     $100 to $500 million (USD)  Travelers, Chubb, Crum & Forster       True
# ...                          ...                               ...        ...
# 2523      $1 to $5 million (USD)                                -1         -1
# 2524     $5 to $10 million (USD)                                -1         -1
# 2525  $100 to $500 million (USD)                                -1         -1
# 2526    Unknown / Non-Applicable                                -1         -1
# 2527    $25 to $50 million (USD)                                -1         -1
#
# [2528 rows x 15 columns]

# %% [markdown]
# ##### Removed the Job Description
# ##### Removed "Easy Apply" because it is a unique feature on Glassdoor job website that allows the applicant to directly apply on Glassdoor instead of going being redirected to the company website application portal
# ##### Both of these columns will not be used for my research question, therefore, are not needed in my dataset

# %%
df2 = df1.drop(['Job Description',"Easy Apply","Competitors","Industry","Sector","Revenue","Type of ownership","Headquarters","Founded"],axis='columns') 
df2.head()
# Out:
#                                            Job Title  \
# 0                                      Data Engineer
# 1  Senior Data Engineer (Healthcare Domain experi...
# 2                                     Data Engineers
# 3                      Client Trade Support Engineer
# 4                                      Data Engineer
#
#                Salary Estimate  Rating                  Company Name  \
# 0  $80K-$150K (Glassdoor est.)     4.5                  Sagence\n4.5
# 1  $80K-$150K (Glassdoor est.)     3.4   Enterprise Integration\n3.4
# 2  $80K-$150K (Glassdoor est.)     5.0     Maestro Technologies\n5.0
# 3  $80K-$150K (Glassdoor est.)     4.8              Jane Street\n4.8
# 4  $80K-$150K (Glassdoor est.)     3.7  GNY Insurance Companies\n3.7
#
#        Location                   Size
# 0  New York, NY      1 to 50 employees
# 1  New York, NY    51 to 200 employees
# 2  New York, NY    51 to 200 employees
# 3  New York, NY  501 to 1000 employees
# 4  New York, NY   201 to 500 employees

# %% [markdown]
# ##### I want to see the datatype of each column to understand how I can wrangle and clean my dataset

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2528 entries, 0 to 2527
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Job Title        2528 non-null   object
#  1   Salary Estimate  2528 non-null   object
#  2   Rating           2528 non-null   float64
#  3   Company Name     2528 non-null   object
#  4   Location         2528 non-null   object
#  5   Size             2528 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 118.6+ KB

# %% [markdown]
# ##### Renaming Rating column to Company Rating

# %%
df2 = df2.rename(columns = {"Rating" : "Company Rating","Size":"Company Size"})

# %% [markdown]
# ##### I want to convert str -1 into str Unknown
# ##### The "Unknown" does appeared in some company information such as revenue, size, and sector so I can assume that "-1" in this dataset is also Unknown
# ##### I checked on https://www.glassdoor.ca/Job/burnaby-engineering-jobs-SRCH_IL.0,7_IC2278200_KO8,19.htm

# %% [markdown]
# ##### For the Company Rating column, I want to turn the int -1 to 0 for the mean calculation to be corrected
# ##### I did a quick mean calculation and printing out the before and after I changed the data values in the Company Rating column
# reference link: https://stackoverflow.com/questions/53587315/pandas-find-specific-value-in-entire-dataframe

# %%
print("Before:",np.mean(df2["Company Rating"]))
df2["Company Rating"].loc[df2["Company Rating"]==-1] = 0.0
print("After:",np.mean(df2["Company Rating"]))
# Out:
# Before: 3.379549050632905
# After: 3.4721123417721427
# C:\Users\myste\miniconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# ##### Replacing str -1 with Unknown in Company Size column

# %%
df2["Company Size"].loc[df2["Company Size"] == "-1"] = "Unknown"

# %% [markdown]
# ##### Remove \n4.5 attached at the end of the Company Name column & (Glassdoor est.) in Salary Estimate column
# ##### Convert str "80K - 150K" in the "Salary Estimate" to int
# referenced link: (in order of what are used below)
# - https://stackoverflow.com/questions/51956572/modify-string-values-of-a-pandas-dataframe-column
# - https://stackoverflow.com/questions/32464280/converting-currency-with-to-numbers-in-python-pandas/32465968
# - https://www.geeksforgeeks.org/python-pandas-split-strings-into-two-list-columns-using-str-split/

# %%
df2["Company Name"] = df2["Company Name"].replace(r'\n.*', '', regex=True)
df2["Salary Estimate"] = df2["Salary Estimate"].replace(r'\(.*', '', regex=True)

df2["Salary Estimate"] = df2["Salary Estimate"].replace('[\$]', '', regex=True)

new = df2["Salary Estimate"].str.split("-", n = 1, expand = True)

df2["Minimum Salary"]= new[0]
df2["Maximum Salary"]= new[1]
df2.drop(columns =["Salary Estimate"],inplace = True)

df2["Minimum Salary"] = df2["Minimum Salary"].replace('K', '', regex=True)
df2["Maximum Salary"] = df2["Maximum Salary"].replace('K', '', regex=True)
df2["Minimum Salary"] = df2["Minimum Salary"].astype(int)
df2["Maximum Salary"] = df2["Maximum Salary"].astype(int)

# %% [markdown]
# ##### Calculating on Min and Max Salary Column

# %%
df2["Minimum Salary"] = df2["Minimum Salary"]*1000
df2["Maximum Salary"] = df2["Maximum Salary"]*1000
df2
# Out:
#                                               Job Title  Company Rating  \
# 0                                         Data Engineer             4.5
# 1     Senior Data Engineer (Healthcare Domain experi...             3.4
# 2                                        Data Engineers             5.0
# 3                         Client Trade Support Engineer             4.8
# 4                                         Data Engineer             3.7
# ...                                                 ...             ...
# 2523                                     Cloud Engineer             4.5
# 2524                                Electrical Engineer             2.9
# 2525                              Sr. Big Data Engineer             3.7
# 2526                     Senior Big Data / ETL Engineer             3.5
# 2527                                     Cloud Engineer             3.6
#
#                               Company Name        Location  \
# 0                                  Sagence    New York, NY
# 1                   Enterprise Integration    New York, NY
# 2                     Maestro Technologies    New York, NY
# 3                              Jane Street    New York, NY
# 4                  GNY Insurance Companies    New York, NY
# ...                                    ...             ...
# 2523                            PMG Global    Westlake, TX
# 2524            Albin Engineering Services  Fort Worth, TX
# 2525  Cincinnati Bell Technology Solutions      Irving, TX
# 2526                                Schwab    Westlake, TX
# 2527        SPECTRAFORCE TECHNOLOGIES Inc.    Westlake, TX
#
#                Company Size  Minimum Salary  Maximum Salary
# 0         1 to 50 employees           80000          150000
# 1       51 to 200 employees           80000          150000
# 2       51 to 200 employees           80000          150000
# 3     501 to 1000 employees           80000          150000
# 4      201 to 500 employees           80000          150000
# ...                     ...             ...             ...
# 2523      1 to 50 employees           76000          128000
# 2524    51 to 200 employees           76000          128000
# 2525  501 to 1000 employees           76000          128000
# 2526                Unknown           76000          128000
# 2527  501 to 1000 employees           76000          128000
#
# [2528 rows x 7 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2528 entries, 0 to 2527
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Job Title       2528 non-null   object
#  1   Company Rating  2528 non-null   float64
#  2   Company Name    2528 non-null   object
#  3   Location        2528 non-null   object
#  4   Company Size    2528 non-null   object
#  5   Minimum Salary  2528 non-null   int32
#  6   Maximum Salary  2528 non-null   int32
# dtypes: float64(1), int32(2), object(4)
# memory usage: 118.6+ KB

# %% [markdown]
# ##### There are a lot of different unique job titles, but with similiar position such as Data Engineer & Data Engineer Python
# ##### In order to use a count plot with job title without clutering the legend or the axes, I only want the simply job title like Data Engineer
# ##### The dataset might be large enough to only include the job with basic title (i.e Data Engineer and Software Engineer)
#
# ##### Create a new dataframe and only include basic job title like Data Engineer, Software Engineer, and Big Data Engineer
#
# referenced link: https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
#unique_job = list(set(df2["Job Title"]))
#unique_job[0:15]
DataEng_data = df2.loc[df2["Job Title"]== "Data Engineer"] #469 rows
SoftEng_data = df2.loc[df2["Job Title"]== "Software Engineer"] #93 rows
BigDataEng_data = df2.loc[df2["Job Title"]== "Big Data Engineer"] #73 rows
frames = [DataEng_data,SoftEng_data,BigDataEng_data]

df3 = pd.concat(frames)
df3 = df3.reset_index()
df3
# Out:
#      index          Job Title  Company Rating  \
# 0        0      Data Engineer             4.5
# 1        4      Data Engineer             3.7
# 2        7      Data Engineer             4.2
# 3       15      Data Engineer             3.8
# 4       16      Data Engineer             4.4
# ..     ...                ...             ...
# 630   2366  Big Data Engineer             3.7
# 631   2373  Big Data Engineer             4.4
# 632   2375  Big Data Engineer             0.0
# 633   2378  Big Data Engineer             3.8
# 634   2394  Big Data Engineer             3.9
#
#                                   Company Name       Location  \
# 0                                      Sagence   New York, NY
# 1                      GNY Insurance Companies   New York, NY
# 2                          NJF Global Holdings   New York, NY
# 3                                      Citadel   New York, NY
# 4                                   PulsePoint   New York, NY
# ..                                         ...            ...
# 630  Tata Consultancy Services (North America)     Irving, TX
# 631                   Tachyon Technologies LLC     Irving, TX
# 632                           Node.Digital LLC  Arlington, TX
# 633                   Enterprise Solutions Inc     Irving, TX
# 634                               Diverse Lynx     Irving, TX
#
#                Company Size  Minimum Salary  Maximum Salary
# 0         1 to 50 employees           80000          150000
# 1      201 to 500 employees           80000          150000
# 2       51 to 200 employees           80000          150000
# 3    1001 to 5000 employees           80000          150000
# 4       51 to 200 employees           80000          150000
# ..                      ...             ...             ...
# 630        10000+ employees           60000          109000
# 631    201 to 500 employees           60000          109000
# 632       1 to 50 employees           60000          109000
# 633     51 to 200 employees           60000          109000
# 634   501 to 1000 employees           30000           60000
#
# [635 rows x 8 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 635 entries, 0 to 634
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           635 non-null    int64
#  1   Job Title       635 non-null    object
#  2   Company Rating  635 non-null    float64
#  3   Company Name    635 non-null    object
#  4   Location        635 non-null    object
#  5   Company Size    635 non-null    object
#  6   Minimum Salary  635 non-null    int32
#  7   Maximum Salary  635 non-null    int32
# dtypes: float64(1), int32(2), int64(1), object(4)
# memory usage: 34.9+ KB

# %% [markdown]
# ##### I am going to categorize the size of the company into small, medium, and large using the Canadian goverment website provided below
# ##### Note, the goverment link is archived so the infornmation is not updated, but it is still a useful guide for categorizing the sizes of the company
# - 1 to to 200 is small
# - 201 to 500 is medium
# - +500 is large
#
# referenced link: https://www150.statcan.gc.ca/n1/pub/11f0027m/2011069/part-partie1-eng.htm

# %%
#unique_size = set(df2["Company Size"])
#unique_size
df3["Company Size"].loc[df3["Company Size"] == "1 to 50 employees"] = "Small"
df3["Company Size"].loc[df3["Company Size"] == "51 to 200 employees"] = "Small"
df3["Company Size"].loc[df3["Company Size"] == "201 to 500 employees"] = "Medium"
df3["Company Size"].loc[df3["Company Size"] == "501 to 1000 employees"] = "Large"
df3["Company Size"].loc[df3["Company Size"] == "1001 to 5000 employees"] = "Large"
df3["Company Size"].loc[df3["Company Size"] == "5001 to 10000 employees"] = "Large"
df3["Company Size"].loc[df3["Company Size"] == "10000+ employees"] = "Large"
df3
# Out:
# C:\Users\myste\miniconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#              Job Title  Company Rating  \
# 0        Data Engineer             4.5
# 1        Data Engineer             3.7
# 2        Data Engineer             4.2
# 3        Data Engineer             3.8
# 4        Data Engineer             4.4
# ..                 ...             ...
# 630  Big Data Engineer             3.7
# 631  Big Data Engineer             4.4
# 632  Big Data Engineer             0.0
# 633  Big Data Engineer             3.8
# 634  Big Data Engineer             3.9
#
#                                   Company Name       Location Company Size  \
# 0                                      Sagence   New York, NY        Small
# 1                      GNY Insurance Companies   New York, NY       Medium
# 2                          NJF Global Holdings   New York, NY        Small
# 3                                      Citadel   New York, NY        Large
# 4                                   PulsePoint   New York, NY        Small
# ..                                         ...            ...          ...
# 630  Tata Consultancy Services (North America)     Irving, TX        Large
# 631                   Tachyon Technologies LLC     Irving, TX       Medium
# 632                           Node.Digital LLC  Arlington, TX        Small
# 633                   Enterprise Solutions Inc     Irving, TX        Small
# 634                               Diverse Lynx     Irving, TX        Large
#
#      Minimum Salary  Maximum Salary
# 0             80000          150000
# 1             80000          150000
# 2             80000          150000
# 3             80000          150000
# 4             80000          150000
# ..              ...             ...
# 630           60000          109000
# 631           60000          109000
# 632           60000          109000
# 633           60000          109000
# 634           30000           60000
#
# [635 rows x 7 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 635 entries, 0 to 634
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           635 non-null    int64
#  1   Job Title       635 non-null    object
#  2   Company Rating  635 non-null    float64
#  3   Company Name    635 non-null    object
#  4   Location        635 non-null    object
#  5   Company Size    635 non-null    object
#  6   Minimum Salary  635 non-null    int32
#  7   Maximum Salary  635 non-null    int32
# dtypes: float64(1), int32(2), int64(1), object(4)
# memory usage: 34.9+ KB
