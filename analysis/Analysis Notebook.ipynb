# %%
import sys
sys.path.append('..')

# %%
from scripts import python_functions as pt

# %%
df = pt.load_and_process('../data/raw/DataEngineer.csv')
# Out:
# C:\Users\myste\miniconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# # Research Question
#
# - ***It is better to work in a small company than a larger one if you want to work in the field of Data Engineering?***

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
font_scale=1.5

# %%
# Please note -1 is unknown Company Rating
fig, ax = plt.subplots(figsize=(15,10))
chart1 = sns.histplot(x="Company Rating",hue="Company Size",multiple="stack",data=df)
plt.title("Company Rating and Company Size Plot")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ***From this graph, small company size seems to have a better company rating than medium and larger company***
#
# ***Medium company still have good company rating***
#
# ***Company rating for large company is leaning toward average***

# %%
# Please note -1 is unknown Company Rating
fig, ax = plt.subplots(figsize=(15,10))
chart2 = sns.histplot(x="Company Rating", 
                      y="Average Salary",
                      hue="Company Size",
                      hue_order=["Large","Medium","Small","Unknown"],
                      data=df)
plt.title("Company Rating Average Salary and Company Size Plot")
# Out:
# Text(0.5, 1.0, 'Company Rating Average Salary and Company Size Plot')

# %% [markdown]
# ***From this graph, it seems that the majority of good company rating peaked at around the average salary 75000 and 110000 USD***

# %%
#Company size and average salary
fig, ax = plt.subplots(figsize=(15,10))
chart3 = sns.histplot(x="Average Salary",hue="Company Size",multiple="stack",data=df)
plt.title("Average Salary and Company Size Plot")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ***This dataset sample pool is reflected on which jobs were available on market at the time when this dataset was collected***
#
# ***That being said, in job market at that time, there were more jobs at a small company and the average salary is higher at a small company as well***

# %%
df_top = df.sort_values("Maximum Salary")
df_top = df_top.reset_index()
df_top = df_top.loc[df["Maximum Salary"]>=215000]

fig, ax = plt.subplots(figsize=(15,10))
plt.xticks(rotation="vertical")
chart4 = sns.barplot(x="Company Name", y="Maximum Salary",hue="Company Size",data=df_top)
plt.title("Top 10 highest paying jobs")
# Out:
# Text(0.5, 1.0, 'Top 10 highest paying jobs')

# %% [markdown]
# ***From this plot, the majority of the highest paying jobs in the field of data engineering is from a small company, and the highest paying job is from a small company***

# %%
df_top = df.sort_values("Minimum Salary")
df_top = df_top.reset_index()
df_top = df_top.loc[df["Minimum Salary"]<=53000]

fig, ax = plt.subplots(figsize=(15,10))
plt.xticks(rotation="vertical")
chart4 = sns.barplot(x="Company Name", y="Minimum Salary",hue="Company Size",data=df_top)
plt.title("Lower paying jobs")
# Out:
# Text(0.5, 1.0, 'Lower paying jobs')

# %% [markdown]
# ***The lowest paying job is from a large company and the majority of lower paying jobs are from large company as well***

# %%
fig, ax = plt.subplots(figsize=(20,10))
chart5 = sns.histplot(x="Company Size",hue="Location",multiple="stack",data=df)
plt.title("Company Size and Its Location Plot")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ***If you want to work for a small company then there are more jobs opening in New York***
#
# ***New York seems to be the place to go if you want a job in Data Engineering, Software Engineering, or Big Data Engineering in any company sizes***

# %% [markdown]
# # Answers to Research Question
#
# - This data shows that small company has better company rating than larger company
# - There are more job opening at a small company than large company with high paying job
# - There are more people being content working at a small company with an average salary between 75000 to 110000 USD
# - If you want to work in the Data Engineering field you should move to New York
#
# ***In conclusion from observing the data, I found that it is better to work for a small company than a large company***
